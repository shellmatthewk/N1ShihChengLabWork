# %%
import random

def parse_graph(edges):
    graph = {}
    animal_map = {"cat": 1, "hippo": 2, "fox": 3, "rabbit": 4, "crocodile": 5, "pig": 6}
    
    for edge in edges:
        nodes = edge.split(',')
        u, v = nodes[0], nodes[1]
        u_num = animal_map[u]
        v_num = animal_map[v]
        
        if u_num not in graph:
            graph[u_num] = []
        if v_num not in graph:
            graph[v_num] = []
        
        graph[u_num].append(v_num)
        graph[v_num].append(u_num)
    
    return graph

def find_eulerian_cycles(graph, num_cycles=50):
    def is_eulerian(graph):
        for node in graph:
            if len(graph[node]) % 2 != 0:
                return False
        return True

    def eulerian_cycle_random(graph):
        start = random.choice(list(graph.keys()))
        stack = [start]
        path = []

        while stack:
            u = stack[-1]
            if graph[u]:
                v = random.choice(graph[u])
                graph[u].remove(v)
                graph[v].remove(u)
                stack.append(v)
            else:
                path.append(stack.pop())
        return path[::-1]

    if not is_eulerian(graph):
        return []

    all_cycles = set()
    original_graph = {node: list(neighbors) for node, neighbors in graph.items()}
    animal_map = {1: "cat", 2: "hippo", 3: "fox", 4: "rabbit", 5: "crocodile", 6: "pig"}
    
    while len(all_cycles) < num_cycles:
        graph_copy = {node: list(neighbors) for node, neighbors in original_graph.items()}
        cycle = eulerian_cycle_random(graph_copy)
        cycle_str = ",".join(map(lambda x: animal_map[x], cycle))
        all_cycles.add(cycle_str)

    return list(all_cycles)

def format_cycles(cycles):
    return "\n".join(cycles)

edges = [
    "cat,hippo,(cat->hippo)", "hippo,cat,(hippo->cat)", "cat,fox,(cat->fox)", "fox,cat,(fox->cat)",
    "cat,rabbit,(cat->rabbit)", "rabbit,cat,(rabbit->cat)", "cat,crocodile,(cat->crocodile)", "crocodile,cat,(crocodile->cat)",
    "cat,pig,(cat->pig)", "pig,cat,(pig->cat)", "hippo,fox,(hippo->fox)", "fox,hippo,(fox->hippo)",
    "hippo,rabbit,(hippo->rabbit)", "rabbit,hippo,(rabbit->hippo)", "hippo,crocodile,(hippo->crocodile)", "crocodile,hippo,(crocodile->hippo)",
    "hippo,pig,(hippo->pig)", "pig,hippo,(pig->hippo)", "fox,rabbit,(fox->rabbit)", "rabbit,fox,(rabbit->fox)",
    "fox,crocodile,(fox->crocodile)", "crocodile,fox,(crocodile->fox)", "fox,pig,(fox->pig)", "pig,fox,(pig->fox)",
    "rabbit,crocodile,(rabbit->crocodile)", "crocodile,rabbit,(crocodile->rabbit)", "rabbit,pig,(rabbit->pig)", "pig,rabbit,(pig->rabbit)",
    "crocodile,pig,(crocodile->pig)", "pig,crocodile,(pig->crocodile)"
]

graph = parse_graph(edges)
cycles = find_eulerian_cycles(graph, num_cycles=100)
formatted_cycles = format_cycles(cycles)

print(formatted_cycles)
# Out:
# hippo,rabbit,crocodile,hippo,fox,cat,crocodile,fox,hippo,cat,rabbit,cat,crocodile,hippo,pig,fox,crocodile,pig,hippo,rabbit,crocodile,pig,rabbit,pig,cat,pig,fox,rabbit,fox,cat,hippo
# cat,crocodile,fox,crocodile,hippo,pig,cat,hippo,fox,pig,crocodile,pig,hippo,fox,rabbit,crocodile,rabbit,hippo,rabbit,pig,fox,rabbit,cat,hippo,crocodile,cat,pig,rabbit,cat,fox,cat
# cat,fox,hippo,fox,pig,hippo,rabbit,pig,crocodile,cat,fox,rabbit,cat,rabbit,pig,fox,crocodile,rabbit,fox,crocodile,pig,hippo,rabbit,crocodile,hippo,cat,pig,cat,crocodile,hippo,cat
# hippo,fox,pig,hippo,crocodile,hippo,cat,crocodile,fox,cat,pig,crocodile,fox,cat,crocodile,pig,rabbit,fox,hippo,rabbit,cat,hippo,rabbit,crocodile,rabbit,cat,pig,rabbit,fox,pig,hippo
# crocodile,hippo,fox,crocodile,fox,pig,fox,cat,hippo,pig,rabbit,crocodile,cat,fox,rabbit,cat,pig,crocodile,cat,hippo,crocodile,pig,rabbit,fox,hippo,pig,cat,rabbit,hippo,rabbit,crocodile
# pig,crocodile,fox,hippo,crocodile,cat,hippo,pig,fox,hippo,crocodile,fox,rabbit,pig,rabbit,crocodile,rabbit,hippo,pig,crocodile,cat,rabbit,hippo,cat,pig,fox,cat,fox,rabbit,cat,pig
# pig,rabbit,pig,hippo,fox,crocodile,hippo,pig,fox,rabbit,cat,pig,crocodile,pig,fox,cat,hippo,cat,rabbit,crocodile,hippo,fox,crocodile,cat,fox,rabbit,hippo,rabbit,crocodile,cat,pig
# hippo,fox,hippo,pig,fox,rabbit,crocodile,hippo,pig,cat,rabbit,hippo,cat,hippo,rabbit,fox,crocodile,fox,pig,cat,fox,cat,crocodile,pig,rabbit,crocodile,cat,rabbit,pig,crocodile,hippo
# rabbit,pig,fox,crocodile,cat,pig,cat,hippo,cat,rabbit,cat,fox,rabbit,hippo,fox,pig,crocodile,hippo,pig,hippo,fox,rabbit,crocodile,pig,rabbit,crocodile,cat,fox,crocodile,hippo,rabbit
# pig,cat,fox,rabbit,fox,hippo,cat,crocodile,fox,cat,rabbit,crocodile,pig,rabbit,pig,hippo,pig,crocodile,rabbit,hippo,cat,pig,fox,hippo,rabbit,cat,crocodile,hippo,crocodile,fox,pig
# hippo,cat,pig,hippo,pig,rabbit,fox,cat,crocodile,cat,pig,fox,pig,crocodile,hippo,fox,cat,hippo,rabbit,fox,crocodile,hippo,rabbit,cat,rabbit,crocodile,pig,rabbit,crocodile,fox,hippo
# cat,crocodile,pig,fox,rabbit,pig,hippo,fox,rabbit,crocodile,hippo,cat,rabbit,hippo,cat,rabbit,crocodile,pig,fox,cat,pig,hippo,crocodile,cat,fox,crocodile,fox,hippo,rabbit,pig,cat
# crocodile,rabbit,cat,crocodile,hippo,fox,cat,fox,crocodile,rabbit,fox,pig,rabbit,pig,cat,pig,crocodile,pig,fox,hippo,cat,hippo,rabbit,hippo,pig,hippo,crocodile,fox,rabbit,cat,crocodile
# cat,crocodile,fox,cat,fox,hippo,crocodile,rabbit,pig,hippo,crocodile,cat,hippo,rabbit,cat,pig,rabbit,fox,pig,hippo,rabbit,cat,hippo,fox,crocodile,rabbit,fox,pig,crocodile,pig,cat
# rabbit,cat,fox,rabbit,crocodile,hippo,cat,pig,crocodile,cat,crocodile,pig,rabbit,hippo,crocodile,rabbit,cat,hippo,pig,cat,fox,rabbit,pig,fox,crocodile,fox,hippo,pig,fox,hippo,rabbit
# hippo,fox,pig,rabbit,cat,hippo,crocodile,rabbit,fox,crocodile,cat,fox,rabbit,pig,hippo,fox,pig,crocodile,fox,cat,pig,hippo,crocodile,rabbit,hippo,cat,pig,crocodile,cat,rabbit,hippo
# crocodile,fox,pig,crocodile,hippo,cat,hippo,crocodile,cat,fox,rabbit,cat,pig,crocodile,rabbit,crocodile,fox,cat,pig,fox,hippo,pig,rabbit,pig,hippo,rabbit,hippo,fox,rabbit,cat,crocodile
# hippo,rabbit,fox,crocodile,pig,hippo,rabbit,cat,pig,rabbit,crocodile,hippo,cat,fox,rabbit,cat,crocodile,fox,pig,crocodile,rabbit,pig,hippo,cat,fox,hippo,fox,pig,cat,crocodile,hippo
# rabbit,hippo,crocodile,hippo,cat,fox,rabbit,pig,rabbit,hippo,fox,pig,cat,rabbit,cat,hippo,pig,fox,crocodile,pig,cat,fox,rabbit,crocodile,cat,crocodile,pig,hippo,fox,crocodile,rabbit
# crocodile,rabbit,hippo,pig,crocodile,fox,rabbit,crocodile,hippo,fox,rabbit,cat,crocodile,fox,pig,rabbit,hippo,pig,cat,fox,cat,hippo,fox,pig,crocodile,hippo,cat,pig,rabbit,cat,crocodile
# cat,rabbit,pig,hippo,cat,rabbit,crocodile,pig,hippo,crocodile,fox,hippo,rabbit,fox,crocodile,cat,pig,fox,hippo,crocodile,rabbit,hippo,cat,pig,crocodile,cat,fox,pig,rabbit,fox,cat
# fox,pig,rabbit,pig,fox,cat,hippo,cat,pig,hippo,crocodile,fox,hippo,rabbit,cat,fox,rabbit,crocodile,fox,hippo,rabbit,crocodile,pig,crocodile,cat,crocodile,hippo,pig,cat,rabbit,fox
# fox,rabbit,cat,hippo,cat,crocodile,cat,pig,crocodile,fox,cat,rabbit,pig,rabbit,crocodile,hippo,pig,fox,cat,pig,crocodile,fox,pig,hippo,rabbit,fox,hippo,rabbit,crocodile,hippo,fox
# hippo,crocodile,fox,pig,rabbit,pig,fox,hippo,rabbit,crocodile,rabbit,cat,pig,hippo,cat,fox,rabbit,hippo,crocodile,pig,cat,fox,crocodile,cat,crocodile,pig,hippo,cat,rabbit,fox,hippo
# rabbit,crocodile,pig,rabbit,pig,hippo,rabbit,fox,cat,pig,fox,hippo,fox,rabbit,cat,rabbit,crocodile,pig,cat,crocodile,fox,cat,hippo,crocodile,hippo,pig,fox,crocodile,cat,hippo,rabbit
# crocodile,cat,pig,crocodile,pig,rabbit,cat,fox,rabbit,pig,hippo,crocodile,rabbit,cat,crocodile,hippo,rabbit,hippo,pig,fox,cat,hippo,cat,pig,fox,rabbit,crocodile,fox,hippo,fox,crocodile
# pig,fox,hippo,crocodile,rabbit,pig,cat,fox,rabbit,hippo,fox,rabbit,cat,fox,crocodile,fox,pig,hippo,pig,cat,hippo,rabbit,pig,crocodile,hippo,cat,crocodile,cat,rabbit,crocodile,pig
# cat,fox,hippo,cat,pig,hippo,pig,fox,pig,rabbit,hippo,rabbit,pig,crocodile,rabbit,fox,crocodile,hippo,cat,rabbit,crocodile,hippo,fox,rabbit,cat,crocodile,cat,fox,crocodile,pig,cat
# rabbit,hippo,crocodile,rabbit,crocodile,cat,rabbit,pig,fox,crocodile,pig,rabbit,fox,rabbit,cat,pig,fox,hippo,cat,pig,crocodile,fox,cat,fox,hippo,crocodile,cat,hippo,pig,hippo,rabbit
# fox,pig,crocodile,hippo,cat,crocodile,fox,hippo,cat,crocodile,fox,cat,pig,crocodile,hippo,rabbit,fox,cat,rabbit,pig,rabbit,crocodile,rabbit,fox,pig,hippo,rabbit,cat,pig,hippo,fox
# pig,fox,crocodile,rabbit,fox,cat,pig,cat,crocodile,pig,hippo,pig,crocodile,rabbit,pig,rabbit,hippo,crocodile,hippo,cat,fox,hippo,fox,rabbit,hippo,cat,rabbit,cat,crocodile,fox,pig
# cat,pig,crocodile,fox,hippo,rabbit,fox,cat,rabbit,cat,fox,hippo,crocodile,rabbit,hippo,cat,hippo,pig,cat,crocodile,pig,fox,rabbit,crocodile,hippo,pig,rabbit,pig,fox,crocodile,cat
# cat,crocodile,fox,cat,hippo,pig,crocodile,pig,fox,rabbit,crocodile,rabbit,cat,hippo,crocodile,cat,pig,cat,rabbit,hippo,crocodile,fox,hippo,fox,pig,hippo,rabbit,pig,rabbit,fox,cat
# pig,fox,cat,hippo,fox,rabbit,crocodile,cat,pig,hippo,rabbit,fox,crocodile,rabbit,hippo,crocodile,fox,cat,crocodile,pig,fox,hippo,crocodile,pig,rabbit,pig,cat,rabbit,cat,hippo,pig
# rabbit,cat,rabbit,pig,crocodile,hippo,cat,crocodile,rabbit,fox,pig,fox,rabbit,crocodile,hippo,cat,pig,crocodile,fox,hippo,rabbit,hippo,pig,cat,fox,cat,crocodile,fox,hippo,pig,rabbit
# hippo,rabbit,crocodile,hippo,cat,pig,rabbit,cat,rabbit,fox,crocodile,cat,hippo,rabbit,fox,cat,crocodile,pig,fox,hippo,pig,crocodile,rabbit,pig,hippo,crocodile,fox,cat,pig,fox,hippo
# crocodile,hippo,fox,rabbit,cat,hippo,rabbit,pig,fox,hippo,pig,fox,rabbit,crocodile,pig,cat,fox,crocodile,rabbit,pig,crocodile,fox,cat,hippo,pig,cat,crocodile,cat,rabbit,hippo,crocodile
# fox,crocodile,cat,pig,rabbit,cat,fox,crocodile,hippo,pig,crocodile,pig,fox,pig,cat,hippo,pig,rabbit,hippo,cat,fox,rabbit,fox,hippo,crocodile,rabbit,crocodile,cat,rabbit,hippo,fox
# cat,pig,crocodile,cat,rabbit,hippo,cat,fox,crocodile,cat,hippo,fox,pig,cat,fox,hippo,crocodile,pig,fox,crocodile,rabbit,pig,rabbit,crocodile,hippo,pig,hippo,rabbit,fox,rabbit,cat
# pig,crocodile,cat,hippo,fox,crocodile,cat,fox,hippo,crocodile,hippo,pig,rabbit,pig,crocodile,rabbit,hippo,cat,rabbit,cat,pig,hippo,rabbit,fox,pig,fox,rabbit,crocodile,fox,cat,pig
# hippo,crocodile,hippo,pig,cat,pig,fox,rabbit,cat,hippo,cat,crocodile,pig,hippo,fox,cat,crocodile,pig,fox,rabbit,crocodile,fox,cat,rabbit,crocodile,fox,hippo,rabbit,pig,rabbit,hippo
# cat,rabbit,pig,crocodile,hippo,fox,cat,crocodile,cat,hippo,pig,fox,crocodile,pig,cat,pig,rabbit,cat,hippo,fox,rabbit,hippo,rabbit,crocodile,fox,rabbit,crocodile,hippo,pig,fox,cat
# rabbit,pig,fox,crocodile,hippo,rabbit,hippo,fox,rabbit,crocodile,cat,fox,rabbit,crocodile,pig,hippo,cat,fox,hippo,pig,cat,crocodile,fox,pig,cat,hippo,crocodile,pig,rabbit,cat,rabbit
# pig,fox,cat,crocodile,fox,pig,crocodile,hippo,fox,rabbit,hippo,pig,crocodile,cat,rabbit,crocodile,fox,hippo,rabbit,pig,hippo,cat,fox,rabbit,crocodile,hippo,cat,pig,rabbit,cat,pig
# cat,hippo,pig,hippo,crocodile,cat,crocodile,pig,rabbit,hippo,fox,pig,crocodile,rabbit,fox,cat,rabbit,hippo,crocodile,fox,hippo,cat,fox,crocodile,rabbit,pig,cat,rabbit,fox,pig,cat
# fox,crocodile,fox,rabbit,cat,fox,cat,hippo,cat,pig,cat,rabbit,pig,fox,hippo,rabbit,hippo,crocodile,cat,crocodile,pig,hippo,fox,rabbit,crocodile,rabbit,pig,crocodile,hippo,pig,fox
# crocodile,fox,crocodile,pig,hippo,fox,hippo,crocodile,hippo,rabbit,fox,cat,pig,fox,pig,rabbit,crocodile,rabbit,pig,hippo,cat,crocodile,pig,cat,hippo,rabbit,cat,fox,rabbit,cat,crocodile
# cat,pig,fox,crocodile,cat,hippo,rabbit,fox,cat,hippo,pig,crocodile,hippo,fox,cat,rabbit,crocodile,fox,rabbit,crocodile,hippo,pig,rabbit,pig,cat,rabbit,hippo,fox,pig,crocodile,cat
# hippo,crocodile,hippo,fox,rabbit,pig,hippo,rabbit,crocodile,fox,hippo,cat,fox,pig,cat,crocodile,pig,hippo,rabbit,fox,pig,cat,rabbit,cat,crocodile,pig,rabbit,crocodile,fox,cat,hippo
# cat,fox,hippo,rabbit,hippo,crocodile,fox,rabbit,cat,pig,fox,hippo,pig,crocodile,rabbit,pig,fox,rabbit,pig,crocodile,rabbit,cat,crocodile,hippo,pig,cat,hippo,cat,fox,crocodile,cat
# cat,pig,rabbit,hippo,cat,rabbit,pig,crocodile,cat,rabbit,hippo,crocodile,pig,fox,cat,fox,pig,cat,hippo,fox,rabbit,crocodile,fox,hippo,pig,hippo,crocodile,fox,rabbit,crocodile,cat
# fox,pig,fox,cat,crocodile,rabbit,hippo,cat,rabbit,fox,crocodile,hippo,pig,crocodile,cat,hippo,fox,hippo,pig,rabbit,cat,fox,crocodile,rabbit,hippo,crocodile,pig,cat,pig,rabbit,fox
# fox,cat,rabbit,pig,fox,rabbit,hippo,crocodile,rabbit,crocodile,pig,cat,hippo,fox,crocodile,cat,pig,crocodile,hippo,pig,hippo,cat,rabbit,fox,pig,rabbit,hippo,fox,cat,crocodile,fox
# cat,hippo,rabbit,cat,hippo,crocodile,pig,fox,pig,rabbit,crocodile,cat,rabbit,pig,cat,fox,hippo,rabbit,fox,hippo,pig,crocodile,cat,pig,hippo,crocodile,rabbit,fox,crocodile,fox,cat
# rabbit,hippo,fox,rabbit,fox,cat,pig,crocodile,pig,fox,crocodile,cat,fox,crocodile,hippo,crocodile,cat,hippo,rabbit,cat,rabbit,pig,hippo,cat,pig,hippo,fox,pig,rabbit,crocodile,rabbit
# fox,cat,fox,hippo,fox,pig,rabbit,cat,pig,rabbit,hippo,rabbit,crocodile,pig,crocodile,fox,pig,cat,crocodile,cat,hippo,pig,hippo,cat,rabbit,fox,rabbit,crocodile,hippo,crocodile,fox
# crocodile,pig,hippo,fox,pig,crocodile,fox,rabbit,cat,hippo,cat,fox,pig,rabbit,hippo,rabbit,fox,hippo,crocodile,cat,rabbit,pig,hippo,crocodile,rabbit,crocodile,cat,pig,cat,fox,crocodile
# cat,fox,pig,cat,hippo,crocodile,pig,cat,hippo,rabbit,cat,crocodile,fox,hippo,pig,rabbit,crocodile,cat,fox,rabbit,fox,pig,hippo,fox,crocodile,hippo,rabbit,pig,crocodile,rabbit,cat
# crocodile,pig,fox,hippo,cat,fox,crocodile,rabbit,fox,hippo,pig,hippo,crocodile,pig,cat,rabbit,pig,rabbit,cat,crocodile,fox,pig,cat,fox,rabbit,crocodile,hippo,rabbit,hippo,cat,crocodile
# crocodile,pig,fox,crocodile,cat,pig,fox,cat,hippo,fox,cat,crocodile,rabbit,fox,hippo,rabbit,hippo,crocodile,hippo,cat,rabbit,fox,crocodile,rabbit,pig,hippo,pig,cat,rabbit,pig,crocodile
# rabbit,crocodile,fox,rabbit,fox,crocodile,pig,cat,fox,pig,hippo,rabbit,cat,pig,rabbit,pig,crocodile,hippo,cat,rabbit,hippo,crocodile,cat,hippo,pig,fox,hippo,fox,cat,crocodile,rabbit
# rabbit,hippo,fox,hippo,cat,crocodile,pig,fox,cat,pig,cat,fox,pig,rabbit,fox,rabbit,crocodile,rabbit,pig,hippo,pig,crocodile,hippo,cat,crocodile,fox,crocodile,hippo,rabbit,cat,rabbit
# cat,rabbit,hippo,fox,cat,pig,hippo,fox,crocodile,rabbit,pig,hippo,crocodile,cat,pig,crocodile,rabbit,hippo,crocodile,cat,rabbit,pig,fox,rabbit,fox,pig,crocodile,fox,cat,hippo,cat
# hippo,rabbit,fox,pig,crocodile,rabbit,cat,pig,rabbit,cat,crocodile,pig,fox,crocodile,hippo,crocodile,rabbit,fox,cat,crocodile,fox,hippo,pig,cat,hippo,cat,fox,hippo,pig,rabbit,hippo
# cat,crocodile,pig,cat,hippo,fox,cat,pig,fox,hippo,rabbit,pig,rabbit,crocodile,hippo,crocodile,cat,rabbit,crocodile,pig,hippo,rabbit,fox,crocodile,fox,cat,rabbit,fox,pig,hippo,cat
# fox,rabbit,hippo,fox,cat,rabbit,crocodile,fox,rabbit,hippo,fox,pig,rabbit,pig,fox,crocodile,rabbit,cat,pig,crocodile,pig,hippo,pig,cat,crocodile,cat,hippo,crocodile,hippo,cat,fox
# rabbit,fox,crocodile,rabbit,fox,cat,hippo,crocodile,cat,crocodile,fox,hippo,fox,pig,hippo,rabbit,hippo,cat,pig,crocodile,pig,cat,fox,pig,rabbit,cat,rabbit,pig,hippo,crocodile,rabbit
# hippo,cat,crocodile,hippo,fox,rabbit,crocodile,cat,fox,cat,pig,cat,hippo,fox,crocodile,rabbit,cat,rabbit,fox,pig,hippo,crocodile,pig,crocodile,fox,pig,rabbit,hippo,pig,rabbit,hippo
# fox,cat,hippo,rabbit,fox,pig,rabbit,cat,crocodile,rabbit,crocodile,hippo,pig,crocodile,fox,cat,rabbit,pig,crocodile,fox,hippo,cat,pig,fox,rabbit,hippo,crocodile,cat,pig,hippo,fox
# cat,rabbit,fox,crocodile,fox,hippo,crocodile,pig,rabbit,cat,hippo,rabbit,fox,hippo,pig,rabbit,hippo,crocodile,rabbit,crocodile,pig,fox,cat,pig,fox,cat,hippo,pig,cat,crocodile,cat
# cat,crocodile,rabbit,hippo,pig,rabbit,cat,pig,cat,hippo,pig,fox,cat,rabbit,hippo,fox,rabbit,pig,fox,hippo,cat,crocodile,fox,crocodile,pig,crocodile,hippo,crocodile,rabbit,fox,cat
# fox,hippo,pig,crocodile,hippo,pig,crocodile,fox,rabbit,pig,cat,crocodile,rabbit,crocodile,fox,rabbit,hippo,crocodile,cat,rabbit,pig,fox,cat,hippo,cat,rabbit,hippo,fox,cat,pig,fox
# cat,fox,crocodile,pig,hippo,pig,fox,crocodile,hippo,cat,rabbit,crocodile,cat,rabbit,pig,crocodile,cat,pig,rabbit,crocodile,hippo,rabbit,fox,pig,cat,fox,hippo,fox,rabbit,hippo,cat
# fox,crocodile,rabbit,pig,hippo,crocodile,hippo,cat,fox,rabbit,pig,fox,pig,cat,crocodile,pig,hippo,fox,cat,pig,crocodile,cat,hippo,rabbit,fox,hippo,rabbit,cat,rabbit,crocodile,fox
# fox,cat,crocodile,cat,pig,hippo,rabbit,pig,crocodile,hippo,cat,pig,fox,rabbit,hippo,pig,crocodile,rabbit,cat,hippo,crocodile,fox,pig,rabbit,crocodile,fox,hippo,fox,cat,rabbit,fox
# crocodile,pig,rabbit,fox,pig,rabbit,crocodile,rabbit,hippo,fox,hippo,crocodile,cat,hippo,cat,fox,pig,hippo,rabbit,cat,pig,crocodile,fox,cat,pig,hippo,crocodile,cat,rabbit,fox,crocodile
# cat,crocodile,fox,hippo,rabbit,fox,pig,crocodile,pig,rabbit,fox,crocodile,hippo,cat,pig,rabbit,crocodile,cat,rabbit,hippo,cat,rabbit,crocodile,hippo,fox,pig,hippo,pig,cat,fox,cat
# hippo,cat,fox,cat,pig,fox,hippo,pig,crocodile,cat,rabbit,cat,hippo,crocodile,hippo,pig,crocodile,rabbit,fox,crocodile,cat,pig,rabbit,fox,pig,rabbit,hippo,rabbit,crocodile,fox,hippo
# pig,fox,hippo,crocodile,rabbit,cat,fox,crocodile,pig,fox,hippo,rabbit,pig,hippo,cat,crocodile,pig,hippo,cat,crocodile,hippo,rabbit,crocodile,fox,cat,rabbit,fox,rabbit,pig,cat,pig
# cat,rabbit,hippo,pig,rabbit,fox,pig,crocodile,fox,hippo,crocodile,hippo,cat,crocodile,rabbit,crocodile,cat,rabbit,fox,cat,pig,crocodile,fox,pig,cat,hippo,pig,rabbit,hippo,fox,cat
# fox,hippo,rabbit,hippo,crocodile,rabbit,crocodile,pig,crocodile,cat,fox,pig,hippo,cat,pig,rabbit,fox,pig,rabbit,cat,hippo,pig,cat,crocodile,fox,hippo,crocodile,fox,rabbit,cat,fox
# crocodile,rabbit,hippo,crocodile,pig,cat,rabbit,pig,crocodile,fox,cat,rabbit,pig,fox,rabbit,fox,pig,cat,crocodile,fox,cat,hippo,cat,crocodile,hippo,pig,hippo,fox,hippo,rabbit,crocodile
# pig,cat,fox,crocodile,cat,rabbit,hippo,pig,hippo,fox,pig,crocodile,fox,rabbit,pig,rabbit,cat,pig,fox,cat,hippo,fox,rabbit,crocodile,rabbit,hippo,crocodile,cat,hippo,crocodile,pig
# fox,cat,crocodile,pig,hippo,crocodile,rabbit,pig,cat,rabbit,pig,cat,hippo,pig,fox,hippo,rabbit,cat,fox,hippo,cat,crocodile,rabbit,hippo,crocodile,pig,fox,rabbit,fox,crocodile,fox
# pig,crocodile,pig,hippo,cat,rabbit,hippo,cat,pig,cat,crocodile,hippo,fox,pig,fox,hippo,crocodile,rabbit,pig,hippo,rabbit,cat,fox,rabbit,crocodile,fox,cat,crocodile,fox,rabbit,pig
# hippo,fox,cat,pig,crocodile,hippo,pig,fox,cat,hippo,rabbit,pig,rabbit,cat,crocodile,fox,crocodile,rabbit,fox,hippo,cat,crocodile,hippo,rabbit,cat,pig,crocodile,rabbit,fox,pig,hippo
# hippo,rabbit,pig,crocodile,cat,fox,rabbit,cat,fox,hippo,pig,cat,pig,rabbit,hippo,fox,rabbit,crocodile,cat,rabbit,crocodile,fox,pig,hippo,crocodile,fox,pig,crocodile,hippo,cat,hippo
# cat,fox,pig,crocodile,fox,rabbit,fox,hippo,crocodile,pig,hippo,crocodile,rabbit,crocodile,cat,rabbit,cat,hippo,rabbit,hippo,pig,rabbit,pig,fox,hippo,cat,crocodile,fox,cat,pig,cat
# cat,pig,hippo,cat,pig,fox,cat,hippo,pig,crocodile,rabbit,crocodile,hippo,rabbit,hippo,fox,rabbit,cat,crocodile,hippo,fox,rabbit,pig,fox,cat,crocodile,fox,crocodile,pig,rabbit,cat
# pig,cat,crocodile,rabbit,pig,hippo,fox,crocodile,pig,cat,hippo,rabbit,cat,crocodile,rabbit,fox,rabbit,cat,fox,crocodile,pig,rabbit,hippo,crocodile,hippo,pig,fox,hippo,cat,fox,pig
# pig,cat,hippo,pig,fox,crocodile,pig,rabbit,cat,fox,rabbit,pig,hippo,rabbit,hippo,fox,pig,crocodile,cat,fox,crocodile,hippo,cat,rabbit,crocodile,rabbit,fox,hippo,crocodile,cat,pig
# fox,hippo,pig,fox,cat,pig,fox,crocodile,rabbit,crocodile,pig,crocodile,fox,cat,rabbit,hippo,pig,rabbit,pig,cat,hippo,crocodile,cat,rabbit,fox,rabbit,hippo,cat,crocodile,hippo,fox
# crocodile,fox,pig,cat,rabbit,fox,rabbit,hippo,pig,crocodile,cat,rabbit,crocodile,hippo,cat,fox,crocodile,hippo,fox,cat,pig,rabbit,crocodile,pig,hippo,fox,pig,rabbit,hippo,cat,crocodile
# rabbit,fox,pig,cat,fox,cat,rabbit,crocodile,pig,rabbit,hippo,pig,rabbit,fox,crocodile,cat,hippo,crocodile,rabbit,hippo,fox,pig,cat,hippo,fox,crocodile,pig,hippo,crocodile,cat,rabbit
# fox,crocodile,fox,rabbit,crocodile,hippo,fox,rabbit,cat,rabbit,pig,rabbit,hippo,cat,crocodile,rabbit,hippo,cat,pig,fox,cat,pig,hippo,fox,cat,crocodile,pig,crocodile,hippo,pig,fox
# rabbit,hippo,pig,crocodile,hippo,rabbit,cat,rabbit,crocodile,fox,hippo,pig,crocodile,hippo,cat,hippo,fox,rabbit,pig,fox,pig,rabbit,crocodile,fox,cat,crocodile,cat,pig,cat,fox,rabbit
# cat,rabbit,cat,hippo,crocodile,cat,pig,fox,pig,crocodile,cat,fox,hippo,crocodile,rabbit,fox,rabbit,hippo,pig,crocodile,fox,crocodile,rabbit,pig,hippo,rabbit,pig,cat,fox,hippo,cat
# fox,hippo,cat,hippo,crocodile,cat,pig,crocodile,fox,pig,cat,fox,hippo,pig,fox,crocodile,hippo,rabbit,pig,crocodile,rabbit,crocodile,cat,fox,rabbit,pig,hippo,rabbit,cat,rabbit,fox
# hippo,cat,rabbit,cat,crocodile,fox,rabbit,pig,crocodile,pig,fox,hippo,rabbit,crocodile,rabbit,pig,cat,fox,pig,hippo,rabbit,fox,cat,hippo,crocodile,fox,hippo,pig,cat,crocodile,hippo
# cat,rabbit,hippo,fox,cat,crocodile,pig,hippo,crocodile,cat,rabbit,fox,cat,hippo,rabbit,crocodile,rabbit,fox,crocodile,fox,pig,crocodile,hippo,cat,pig,fox,hippo,pig,rabbit,pig,cat

# %%
with open("raw_seeds","w") as file:
    for cycle in cycles:
        file.write(f"{cycle}\n")
