# %%
import math
import numpy as np # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore
from matplotlib.patches import Rectangle # type: ignore 
import seaborn as sns # type: ignore
from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data = "Session_24_06_2024_HR13_MIN40_SEC59_added_cols.csv"
cls = ["TrackingStamp", "TimeStamp", "X", "Y", "Angle", "PosterNumber", "TrialStamp"]
df = pd.read_csv(data, skiprows=53, names=cls)

stamp, time, x, y, yaw = np.loadtxt("Session_25_06_2024_HR11_MIN57_SEC50.txt", skiprows=47, unpack = True)

# Create tuples with information of each poster 
posters = [
    (1, -12.27, -1.87, "Cat"), 
    (2, -2.77, 12.26, "Hippo"), 
    (3, 2.23, -1.87, "Fox"), 
    (4, 2.23, 7.63, "Rabbit"), 
    (5, -12.27, 17.13, "Crocodile"), 
    (6, -12.27, 7.63, "Pig")
    ]

x_max = max(x)
x_min = min(x)
y_max = max(y)
y_min = min(y)

dfs = []
index = df.index[df['TrialStamp'] == 1].tolist() 
index = [0] + index + [len(df)]
for i in range(len(index) - 1):
    starting_index = index[i]
    ending_index = index[i+1]
    new_df = df.iloc[starting_index:ending_index]
    dfs.append(new_df)
for i, df in enumerate(dfs):
    print(f"DataFrame {i+1}:\n{df}\n")
if dfs:
    dfs.pop(0)
# Out:
# DataFrame 1:
# Empty DataFrame
# Columns: [TrackingStamp, TimeStamp, X, Y, Angle, PosterNumber, TrialStamp]
# Index: []
#
# DataFrame 2:
#      TrackingStamp  TimeStamp       X       Y    Angle  PosterNumber  \
# 0               11   0.020000  1.8623  7.1561  31.4827             1
# 1                0   0.016787  1.8623  7.1561  31.4827             0
# 2                0   0.016624  1.8623  7.1561  31.4827             0
# 3                0   0.016474  1.8623  7.1561  31.4827             0
# 4                0   0.016474  1.8623  7.1561  31.4827             0
# ..             ...        ...     ...     ...      ...           ...
# 647              0   0.016696 -7.0700 -4.8000   0.0000             0
# 648              0   0.016696 -7.0700 -4.8000   0.0000             0
# 649              0   0.016607 -7.0700 -4.8000   0.0000             0
# 650              0   0.016696 -7.0700 -4.8000   0.0000             0
# 651              0   0.016599 -7.0700 -4.8000   0.0000             0
#
#      TrialStamp
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 647           0
# 648           0
# 649           0
# 650           0
# 651           0
#
# [652 rows x 7 columns]
#
# DataFrame 3:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 652              14   0.016748 -7.07 -4.8    0.0             4           1
# 653               0   0.016755 -7.07 -4.8    0.0             0           0
# 654               0   0.016409 -7.07 -4.8    0.0             0           0
# 655               0   0.016804 -7.07 -4.8    0.0             0           0
# 656               0   0.016689 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 1902              0   0.016509 -7.07 -4.8    0.0             0           0
# 1903              0   0.016782 -7.07 -4.8    0.0             0           0
# 1904              0   0.016721 -7.07 -4.8    0.0             0           0
# 1905              0   0.016056 -7.07 -4.8    0.0             0           0
# 1906              0   0.017025 -7.07 -4.8    0.0             0           0
#
# [1255 rows x 7 columns]
#
# DataFrame 4:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 1907             13   0.016811 -7.07 -4.8    0.0             3           1
# 1908              0   0.016896 -7.07 -4.8    0.0             0           0
# 1909              0   0.016562 -7.07 -4.8    0.0             0           0
# 1910              0   0.016549 -7.07 -4.8    0.0             0           0
# 1911              0   0.016794 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 2382              0   0.016677 -7.07 -4.8    0.0             0           0
# 2383              0   0.016735 -7.07 -4.8    0.0             0           0
# 2384              0   0.017068 -7.07 -4.8    0.0             0           0
# 2385              0   0.016112 -7.07 -4.8    0.0             0           0
# 2386              0   0.016799 -7.07 -4.8    0.0             0           0
#
# [480 rows x 7 columns]
#
# DataFrame 5:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 2387             12   0.016402 -7.07 -4.8    0.0             2           1
# 2388              0   0.016905 -7.07 -4.8    0.0             0           0
# 2389              0   0.016534 -7.07 -4.8    0.0             0           0
# 2390              0   0.016663 -7.07 -4.8    0.0             0           0
# 2391              0   0.016912 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 3089              0   0.016700 -7.07 -4.8    0.0             0           0
# 3090              0   0.016596 -7.07 -4.8    0.0             0           0
# 3091              0   0.016921 -7.07 -4.8    0.0             0           0
# 3092              0   0.016386 -7.07 -4.8    0.0             0           0
# 3093              0   0.016788 -7.07 -4.8    0.0             0           0
#
# [707 rows x 7 columns]
#
# DataFrame 6:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 3094             13   0.016504 -7.07 -4.8    0.0             3           1
# 3095              0   0.016738 -7.07 -4.8    0.0             0           0
# 3096              0   0.016471 -7.07 -4.8    0.0             0           0
# 3097              0   0.016808 -7.07 -4.8    0.0             0           0
# 3098              0   0.016597 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 3860              0   0.016577 -7.07 -4.8    0.0             0           0
# 3861              0   0.016795 -7.07 -4.8    0.0             0           0
# 3862              0   0.016493 -7.07 -4.8    0.0             0           0
# 3863              0   0.016800 -7.07 -4.8    0.0             0           0
# 3864              0   0.016507 -7.07 -4.8    0.0             0           0
#
# [771 rows x 7 columns]
#
# DataFrame 7:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 3865             14   0.016474 -7.07 -4.8    0.0             4           1
# 3866              0   0.017029 -7.07 -4.8    0.0             0           0
# 3867              0   0.016592 -7.07 -4.8    0.0             0           0
# 3868              0   0.016703 -7.07 -4.8    0.0             0           0
# 3869              0   0.016646 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 4659              0   0.016782 -7.07 -4.8    0.0             0           0
# 4660              0   0.016996 -7.07 -4.8    0.0             0           0
# 4661              0   0.016712 -7.07 -4.8    0.0             0           0
# 4662              0   0.016694 -7.07 -4.8    0.0             0           0
# 4663              0   0.016435 -7.07 -4.8    0.0             0           0
#
# [799 rows x 7 columns]
#
# DataFrame 8:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 4664             13   0.016601 -7.07 -4.8    0.0             3           1
# 4665              0   0.016961 -7.07 -4.8    0.0             0           0
# 4666              0   0.016127 -7.07 -4.8    0.0             0           0
# 4667              0   0.016791 -7.07 -4.8    0.0             0           0
# 4668              0   0.016639 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 5077              0   0.016742 -7.07 -4.8    0.0             0           0
# 5078              0   0.016772 -7.07 -4.8    0.0             0           0
# 5079              0   0.016685 -7.07 -4.8    0.0             0           0
# 5080              0   0.016610 -7.07 -4.8    0.0             0           0
# 5081              0   0.016690 -7.07 -4.8    0.0             0           0
#
# [418 rows x 7 columns]
#
# DataFrame 9:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 5082             15   0.016500 -7.07 -4.8    0.0             5           1
# 5083              0   0.016791 -7.07 -4.8    0.0             0           0
# 5084              0   0.016518 -7.07 -4.8    0.0             0           0
# 5085              0   0.016932 -7.07 -4.8    0.0             0           0
# 5086              0   0.016563 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 5974              0   0.016408 -7.07 -4.8    0.0             0           0
# 5975              0   0.016890 -7.07 -4.8    0.0             0           0
# 5976              0   0.016702 -7.07 -4.8    0.0             0           0
# 5977              0   0.016644 -7.07 -4.8    0.0             0           0
# 5978              0   0.016983 -7.07 -4.8    0.0             0           0
#
# [897 rows x 7 columns]
#
# DataFrame 10:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 5979             11   0.016544 -7.07 -4.8    0.0             1           1
# 5980              0   0.016767 -7.07 -4.8    0.0             0           0
# 5981              0   0.016494 -7.07 -4.8    0.0             0           0
# 5982              0   0.016815 -7.07 -4.8    0.0             0           0
# 5983              0   0.016403 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 6667              0   0.016686 -7.07 -4.8    0.0             0           0
# 6668              0   0.016414 -7.07 -4.8    0.0             0           0
# 6669              0   0.016583 -7.07 -4.8    0.0             0           0
# 6670              0   0.016357 -7.07 -4.8    0.0             0           0
# 6671              0   0.016822 -7.07 -4.8    0.0             0           0
#
# [693 rows x 7 columns]
#
# DataFrame 11:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 6672             15   0.016725 -7.07 -4.8    0.0             5           1
# 6673              0   0.016876 -7.07 -4.8    0.0             0           0
# 6674              0   0.016500 -7.07 -4.8    0.0             0           0
# 6675              0   0.016709 -7.07 -4.8    0.0             0           0
# 6676              0   0.016694 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 7690              0   0.016807 -7.07 -4.8    0.0             0           0
# 7691              0   0.016570 -7.07 -4.8    0.0             0           0
# 7692              0   0.016606 -7.07 -4.8    0.0             0           0
# 7693              0   0.016804 -7.07 -4.8    0.0             0           0
# 7694              0   0.016389 -7.07 -4.8    0.0             0           0
#
# [1023 rows x 7 columns]
#
# DataFrame 12:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 7695             11   0.016798 -7.07 -4.8    0.0             1           1
# 7696              0   0.017187 -7.07 -4.8    0.0             0           0
# 7697              0   0.016531 -7.07 -4.8    0.0             0           0
# 7698              0   0.016377 -7.07 -4.8    0.0             0           0
# 7699              0   0.016602 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 8099              0   0.016701 -7.07 -4.8    0.0             0           0
# 8100              0   0.016702 -7.07 -4.8    0.0             0           0
# 8101              0   0.016796 -7.07 -4.8    0.0             0           0
# 8102              0   0.016499 -7.07 -4.8    0.0             0           0
# 8103              0   0.016601 -7.07 -4.8    0.0             0           0
#
# [409 rows x 7 columns]
#
# DataFrame 13:
#       TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 8104             13   0.016620 -7.07 -4.8    0.0             3           1
# 8105              0   0.016877 -7.07 -4.8    0.0             0           0
# 8106              0   0.016503 -7.07 -4.8    0.0             0           0
# 8107              0   0.016824 -7.07 -4.8    0.0             0           0
# 8108              0   0.016577 -7.07 -4.8    0.0             0           0
# ...             ...        ...   ...  ...    ...           ...         ...
# 8520              0   0.016383 -7.07 -4.8    0.0             0           0
# 8521              0   0.016825 -7.07 -4.8    0.0             0           0
# 8522              0   0.016684 -7.07 -4.8    0.0             0           0
# 8523              0   0.016620 -7.07 -4.8    0.0             0           0
# 8524              0   0.016780 -7.07 -4.8    0.0             0           0
#
# [421 rows x 7 columns]
#
# DataFrame 14:
#       TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 8525             15   0.016505 -7.07 -4.8    0.0000             5           1
# 8526              0   0.016796 -7.07 -4.8    0.0000             0           0
# 8527              0   0.016408 -7.07 -4.8    0.0000             0           0
# 8528              0   0.016713 -7.07 -4.8    0.0000             0           0
# 8529              0   0.016803 -7.07 -4.8    0.0000             0           0
# ...             ...        ...   ...  ...       ...           ...         ...
# 9048              0   0.016703 -7.07 -4.8  347.2036             0           0
# 9049              0   0.016786 -7.07 -4.8  346.9242             0           0
# 9050              0   0.016703 -7.07 -4.8  346.9242             0           0
# 9051              0   0.016496 -7.07 -4.8  346.9242             0           0
# 9052              0   0.016703 -7.07 -4.8  346.9242             0           0
#
# [528 rows x 7 columns]
#
# DataFrame 15:
#       TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 9053             11   0.016494 -7.07 -4.8  346.9242             1           1
# 9054              0   0.016821 -7.07 -4.8  346.9242             0           0
# 9055              0   0.016485 -7.07 -4.8  346.9242             0           0
# 9056              0   0.016801 -7.07 -4.8  346.9242             0           0
# 9057              0   0.016710 -7.07 -4.8  346.9242             0           0
# ...             ...        ...   ...  ...       ...           ...         ...
# 9526              0   0.016592 -7.07 -4.8    0.0000             0           0
# 9527              0   0.016711 -7.07 -4.8    0.0000             0           0
# 9528              0   0.016703 -7.07 -4.8    0.0000             0           0
# 9529              0   0.016591 -7.07 -4.8    0.0000             0           0
# 9530              0   0.016897 -7.07 -4.8    0.0000             0           0
#
# [478 rows x 7 columns]
#
# DataFrame 16:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 9531              16   0.016296 -7.07 -4.8    0.0             6           1
# 9532               0   0.017102 -7.07 -4.8    0.0             0           0
# 9533               0   0.016307 -7.07 -4.8    0.0             0           0
# 9534               0   0.016799 -7.07 -4.8    0.0             0           0
# 9535               0   0.016704 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 10406              0   0.016724 -7.07 -4.8    0.0             0           0
# 10407              0   0.016678 -7.07 -4.8    0.0             0           0
# 10408              0   0.016694 -7.07 -4.8    0.0             0           0
# 10409              0   0.016601 -7.07 -4.8    0.0             0           0
# 10410              0   0.016502 -7.07 -4.8    0.0             0           0
#
# [880 rows x 7 columns]
#
# DataFrame 17:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 10411             11   0.016804 -7.07 -4.8    0.0             1           1
# 10412              0   0.016696 -7.07 -4.8    0.0             0           0
# 10413              0   0.016605 -7.07 -4.8    0.0             0           0
# 10414              0   0.016702 -7.07 -4.8    0.0             0           0
# 10415              0   0.016605 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 10827              0   0.016599 -7.07 -4.8    0.0             0           0
# 10828              0   0.016701 -7.07 -4.8    0.0             0           0
# 10829              0   0.016798 -7.07 -4.8    0.0             0           0
# 10830              0   0.016704 -7.07 -4.8    0.0             0           0
# 10831              0   0.016430 -7.07 -4.8    0.0             0           0
#
# [421 rows x 7 columns]
#
# DataFrame 18:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 10832             16   0.016871 -7.07 -4.8    0.0             6           1
# 10833              0   0.016799 -7.07 -4.8    0.0             0           0
# 10834              0   0.016409 -7.07 -4.8    0.0             0           0
# 10835              0   0.016695 -7.07 -4.8    0.0             0           0
# 10836              0   0.016715 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 11294              0   0.016594 -7.07 -4.8    0.0             0           0
# 11295              0   0.016602 -7.07 -4.8    0.0             0           0
# 11296              0   0.016723 -7.07 -4.8    0.0             0           0
# 11297              0   0.016664 -7.07 -4.8    0.0             0           0
# 11298              0   0.016707 -7.07 -4.8    0.0             0           0
#
# [467 rows x 7 columns]
#
# DataFrame 19:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 11299             12   0.016503 -7.07 -4.8    0.0             2           1
# 11300              0   0.017151 -7.07 -4.8    0.0             0           0
# 11301              0   0.016257 -7.07 -4.8    0.0             0           0
# 11302              0   0.016609 -7.07 -4.8    0.0             0           0
# 11303              0   0.016908 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 12144              0   0.016496 -7.07 -4.8    0.0             0           0
# 12145              0   0.016798 -7.07 -4.8    0.0             0           0
# 12146              0   0.016599 -7.07 -4.8    0.0             0           0
# 12147              0   0.016810 -7.07 -4.8    0.0             0           0
# 12148              0   0.016408 -7.07 -4.8    0.0             0           0
#
# [850 rows x 7 columns]
#
# DataFrame 20:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 12149             15   0.016684 -7.07 -4.8    0.0             5           1
# 12150              0   0.016940 -7.07 -4.8    0.0             0           0
# 12151              0   0.016460 -7.07 -4.8    0.0             0           0
# 12152              0   0.016596 -7.07 -4.8    0.0             0           0
# 12153              0   0.016904 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 12688              0   0.016824 -7.07 -4.8    0.0             0           0
# 12689              0   0.016570 -7.07 -4.8    0.0             0           0
# 12690              0   0.016601 -7.07 -4.8    0.0             0           0
# 12691              0   0.016517 -7.07 -4.8    0.0             0           0
# 12692              0   0.016889 -7.07 -4.8    0.0             0           0
#
# [544 rows x 7 columns]
#
# DataFrame 21:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 12693             14   0.016422 -7.07 -4.8   0.0000             4           1
# 12694              0   0.016875 -7.07 -4.8   0.0000             0           0
# 12695              0   0.016600 -7.07 -4.8   0.0000             0           0
# 12696              0   0.016630 -7.07 -4.8   0.0000             0           0
# 12697              0   0.016674 -7.07 -4.8   0.0000             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 13139              0   0.016696 -7.07 -4.8  17.1877             0           0
# 13140              0   0.016610 -7.07 -4.8  17.1877             0           0
# 13141              0   0.016780 -7.07 -4.8  17.1877             0           0
# 13142              0   0.016699 -7.07 -4.8  17.1877             0           0
# 13143              0   0.016518 -7.07 -4.8  17.1877             0           0
#
# [451 rows x 7 columns]
#
# DataFrame 22:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 13144             11   0.016682 -7.07 -4.8  17.1877             1           1
# 13145              0   0.016801 -7.07 -4.8  17.1877             0           0
# 13146              0   0.016505 -7.07 -4.8  17.1877             0           0
# 13147              0   0.016828 -7.07 -4.8  17.1877             0           0
# 13148              0   0.016668 -7.07 -4.8  17.1877             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 13907              0   0.016769 -7.07 -4.8   0.0000             0           0
# 13908              0   0.016704 -7.07 -4.8   0.0000             0           0
# 13909              0   0.016610 -7.07 -4.8   0.0000             0           0
# 13910              0   0.016595 -7.07 -4.8   0.0000             0           0
# 13911              0   0.016722 -7.07 -4.8   0.0000             0           0
#
# [768 rows x 7 columns]
#
# DataFrame 23:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 13912             13   0.016567 -7.07 -4.8    0.0             3           1
# 13913              0   0.016805 -7.07 -4.8    0.0             0           0
# 13914              0   0.016593 -7.07 -4.8    0.0             0           0
# 13915              0   0.016707 -7.07 -4.8    0.0             0           0
# 13916              0   0.016684 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 14687              0   0.016713 -7.07 -4.8    0.0             0           0
# 14688              0   0.016707 -7.07 -4.8    0.0             0           0
# 14689              0   0.016672 -7.07 -4.8    0.0             0           0
# 14690              0   0.016241 -7.07 -4.8    0.0             0           0
# 14691              0   0.016558 -7.07 -4.8    0.0             0           0
#
# [780 rows x 7 columns]
#
# DataFrame 24:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 14692             15   0.016705 -7.07 -4.8    0.0000             5           1
# 14693              0   0.016898 -7.07 -4.8    0.0000             0           0
# 14694              0   0.016410 -7.07 -4.8    0.0000             0           0
# 14695              0   0.016895 -7.07 -4.8    0.0000             0           0
# 14696              0   0.016583 -7.07 -4.8    0.0000             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 15232              0   0.016614 -7.07 -4.8  346.9405             0           0
# 15233              0   0.016789 -7.07 -4.8  346.6611             0           0
# 15234              0   0.016827 -7.07 -4.8  346.6611             0           0
# 15235              0   0.016380 -7.07 -4.8  346.6611             0           0
# 15236              0   0.016709 -7.07 -4.8  346.6611             0           0
#
# [545 rows x 7 columns]
#
# DataFrame 25:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 15237             16   0.016694 -7.07 -4.8  346.6611             6           1
# 15238              0   0.016787 -7.07 -4.8  346.6611             0           0
# 15239              0   0.016643 -7.07 -4.8  346.6611             0           0
# 15240              0   0.016601 -7.07 -4.8  346.6611             0           0
# 15241              0   0.016557 -7.07 -4.8  346.6611             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 15920              0   0.016585 -7.07 -4.8    0.0000             0           0
# 15921              0   0.017213 -7.07 -4.8    0.0000             0           0
# 15922              0   0.016173 -7.07 -4.8    0.0000             0           0
# 15923              0   0.016812 -7.07 -4.8    0.0000             0           0
# 15924              0   0.016315 -7.07 -4.8    0.0000             0           0
#
# [688 rows x 7 columns]
#
# DataFrame 26:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 15925             15   0.016696 -7.07 -4.8    0.0             5           1
# 15926              0   0.016973 -7.07 -4.8    0.0             0           0
# 15927              0   0.016499 -7.07 -4.8    0.0             0           0
# 15928              0   0.016704 -7.07 -4.8    0.0             0           0
# 15929              0   0.016594 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 16482              0   0.016713 -7.07 -4.8    0.0             0           0
# 16483              0   0.016771 -7.07 -4.8    0.0             0           0
# 16484              0   0.016494 -7.07 -4.8    0.0             0           0
# 16485              0   0.016737 -7.07 -4.8    0.0             0           0
# 16486              0   0.016767 -7.07 -4.8    0.0             0           0
#
# [562 rows x 7 columns]
#
# DataFrame 27:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 16487             16   0.016479 -7.07 -4.8    0.0             6           1
# 16488              0   0.016820 -7.07 -4.8    0.0             0           0
# 16489              0   0.016515 -7.07 -4.8    0.0             0           0
# 16490              0   0.016794 -7.07 -4.8    0.0             0           0
# 16491              0   0.016591 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 16966              0   0.016787 -7.07 -4.8    0.0             0           0
# 16967              0   0.016709 -7.07 -4.8    0.0             0           0
# 16968              0   0.016801 -7.07 -4.8    0.0             0           0
# 16969              0   0.016592 -7.07 -4.8    0.0             0           0
# 16970              0   0.016619 -7.07 -4.8    0.0             0           0
#
# [484 rows x 7 columns]
#
# DataFrame 28:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 16971             15   0.016724 -7.07 -4.8    0.0000             5           1
# 16972              0   0.016841 -7.07 -4.8    0.0000             0           0
# 16973              0   0.016523 -7.07 -4.8    0.0000             0           0
# 16974              0   0.016492 -7.07 -4.8    0.0000             0           0
# 16975              0   0.016814 -7.07 -4.8    0.0000             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 17566              0   0.016511 -7.07 -4.8  346.9338             0           0
# 17567              0   0.016883 -7.07 -4.8  346.9338             0           0
# 17568              0   0.016545 -7.07 -4.8  346.9338             0           0
# 17569              0   0.016760 -7.07 -4.8  346.9338             0           0
# 17570              0   0.016698 -7.07 -4.8  346.9338             0           0
#
# [600 rows x 7 columns]
#
# DataFrame 29:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 17571             11   0.016282 -7.07 -4.8  346.9338             1           1
# 17572              0   0.017054 -7.07 -4.8  346.9338             0           0
# 17573              0   0.016661 -7.07 -4.8  346.9338             0           0
# 17574              0   0.016500 -7.07 -4.8  346.9338             0           0
# 17575              0   0.016698 -7.07 -4.8  346.9338             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 18057              0   0.016868 -7.07 -4.8    0.0000             0           0
# 18058              0   0.016700 -7.07 -4.8    0.0000             0           0
# 18059              0   0.016759 -7.07 -4.8    0.0000             0           0
# 18060              0   0.016532 -7.07 -4.8    0.0000             0           0
# 18061              0   0.016722 -7.07 -4.8    0.0000             0           0
#
# [491 rows x 7 columns]
#
# DataFrame 30:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 18062             15   0.016675 -7.07 -4.8    0.0000             5           1
# 18063              0   0.016916 -7.07 -4.8    0.0000             0           0
# 18064              0   0.016479 -7.07 -4.8    0.0000             0           0
# 18065              0   0.016836 -7.07 -4.8    0.0000             0           0
# 18066              0   0.016271 -7.07 -4.8    0.0000             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 18576              0   0.016935 -7.07 -4.8  337.2155             0           0
# 18577              0   0.016357 -7.07 -4.8  337.2155             0           0
# 18578              0   0.016711 -7.07 -4.8  337.2155             0           0
# 18579              0   0.016697 -7.07 -4.8  337.2155             0           0
# 18580              0   0.016499 -7.07 -4.8  337.2155             0           0
#
# [519 rows x 7 columns]
#
# DataFrame 31:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 18581             13   0.016892 -7.07 -4.8  337.2155             3           1
# 18582              0   0.016705 -7.07 -4.8  337.2155             0           0
# 18583              0   0.016506 -7.07 -4.8  337.2155             0           0
# 18584              0   0.016613 -7.07 -4.8  337.2155             0           0
# 18585              0   0.016669 -7.07 -4.8  337.2155             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 19074              0   0.016791 -7.07 -4.8    0.0000             0           0
# 19075              0   0.016287 -7.07 -4.8    0.0000             0           0
# 19076              0   0.017131 -7.07 -4.8    0.0000             0           0
# 19077              0   0.016579 -7.07 -4.8    0.0000             0           0
# 19078              0   0.016701 -7.07 -4.8    0.0000             0           0
#
# [498 rows x 7 columns]
#
# DataFrame 32:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 19079             15   0.016496 -7.07 -4.8    0.0000             5           1
# 19080              0   0.016723 -7.07 -4.8    0.0000             0           0
# 19081              0   0.016593 -7.07 -4.8    0.0000             0           0
# 19082              0   0.016892 -7.07 -4.8    0.0000             0           0
# 19083              0   0.016544 -7.07 -4.8    0.0000             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 19613              0   0.016740 -7.07 -4.8  346.9279             0           0
# 19614              0   0.016573 -7.07 -4.8  346.9279             0           0
# 19615              0   0.016714 -7.07 -4.8  346.9279             0           0
# 19616              0   0.016586 -7.07 -4.8  346.9279             0           0
# 19617              0   0.016682 -7.07 -4.8  346.9279             0           0
#
# [539 rows x 7 columns]
#
# DataFrame 33:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 19618             16   0.016711 -7.07 -4.8  346.9279             6           1
# 19619              0   0.016688 -7.07 -4.8  346.9279             0           0
# 19620              0   0.016505 -7.07 -4.8  346.9279             0           0
# 19621              0   0.016798 -7.07 -4.8  346.9279             0           0
# 19622              0   0.016702 -7.07 -4.8  346.9279             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 20106              0   0.016794 -7.07 -4.8    0.0000             0           0
# 20107              0   0.016614 -7.07 -4.8    0.0000             0           0
# 20108              0   0.016761 -7.07 -4.8    0.0000             0           0
# 20109              0   0.016509 -7.07 -4.8    0.0000             0           0
# 20110              0   0.016796 -7.07 -4.8    0.0000             0           0
#
# [493 rows x 7 columns]
#
# DataFrame 34:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 20111             13   0.016536 -7.07 -4.8    0.0             3           1
# 20112              0   0.016868 -7.07 -4.8    0.0             0           0
# 20113              0   0.016399 -7.07 -4.8    0.0             0           0
# 20114              0   0.016902 -7.07 -4.8    0.0             0           0
# 20115              0   0.016543 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 20565              0   0.016798 -7.07 -4.8    0.0             0           0
# 20566              0   0.016601 -7.07 -4.8    0.0             0           0
# 20567              0   0.016694 -7.07 -4.8    0.0             0           0
# 20568              0   0.016714 -7.07 -4.8    0.0             0           0
# 20569              0   0.016693 -7.07 -4.8    0.0             0           0
#
# [459 rows x 7 columns]
#
# DataFrame 35:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 20570             11   0.016358 -7.07 -4.8    0.0             1           1
# 20571              0   0.017052 -7.07 -4.8    0.0             0           0
# 20572              0   0.016485 -7.07 -4.8    0.0             0           0
# 20573              0   0.016539 -7.07 -4.8    0.0             0           0
# 20574              0   0.016959 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 20989              0   0.016920 -7.07 -4.8    0.0             0           0
# 20990              0   0.016598 -7.07 -4.8    0.0             0           0
# 20991              0   0.016627 -7.07 -4.8    0.0             0           0
# 20992              0   0.016673 -7.07 -4.8    0.0             0           0
# 20993              0   0.016819 -7.07 -4.8    0.0             0           0
#
# [424 rows x 7 columns]
#
# DataFrame 36:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 20994             12   0.017000 -7.07 -4.8    0.0             2           1
# 20995              0   0.016672 -7.07 -4.8    0.0             0           0
# 20996              0   0.016693 -7.07 -4.8    0.0             0           0
# 20997              0   0.016525 -7.07 -4.8    0.0             0           0
# 20998              0   0.016403 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 21816              0   0.016634 -7.07 -4.8    0.0             0           0
# 21817              0   0.016336 -7.07 -4.8    0.0             0           0
# 21818              0   0.017020 -7.07 -4.8    0.0             0           0
# 21819              0   0.016732 -7.07 -4.8    0.0             0           0
# 21820              0   0.016468 -7.07 -4.8    0.0             0           0
#
# [827 rows x 7 columns]
#
# DataFrame 37:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 21821             14   0.016807 -7.07 -4.8   0.0000             4           1
# 21822              0   0.016795 -7.07 -4.8   0.0000             0           0
# 21823              0   0.016647 -7.07 -4.8   0.0000             0           0
# 21824              0   0.016560 -7.07 -4.8   0.0000             0           0
# 21825              0   0.016591 -7.07 -4.8   0.0000             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 22227              0   0.016572 -7.07 -4.8  34.4047             0           0
# 22228              0   0.016755 -7.07 -4.8  34.4047             0           0
# 22229              0   0.016655 -7.07 -4.8  34.4047             0           0
# 22230              0   0.016704 -7.07 -4.8  34.4047             0           0
# 22231              0   0.016910 -7.07 -4.8  34.4047             0           0
#
# [411 rows x 7 columns]
#
# DataFrame 38:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 22232             13   0.016288 -7.07 -4.8  34.4047             3           1
# 22233              0   0.016926 -7.07 -4.8  34.4047             0           0
# 22234              0   0.016476 -7.07 -4.8  34.4047             0           0
# 22235              0   0.016797 -7.07 -4.8  34.4047             0           0
# 22236              0   0.016606 -7.07 -4.8  34.4047             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 22642              0   0.016717 -7.07 -4.8   0.0000             0           0
# 22643              0   0.016669 -7.07 -4.8   0.0000             0           0
# 22644              0   0.016704 -7.07 -4.8   0.0000             0           0
# 22645              0   0.016601 -7.07 -4.8   0.0000             0           0
# 22646              0   0.016701 -7.07 -4.8   0.0000             0           0
#
# [415 rows x 7 columns]
#
# DataFrame 39:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 22647             11   0.016502 -7.07 -4.8    0.0             1           1
# 22648              0   0.017000 -7.07 -4.8    0.0             0           0
# 22649              0   0.016489 -7.07 -4.8    0.0             0           0
# 22650              0   0.016709 -7.07 -4.8    0.0             0           0
# 22651              0   0.016612 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 23052              0   0.016722 -7.07 -4.8    0.0             0           0
# 23053              0   0.016692 -7.07 -4.8    0.0             0           0
# 23054              0   0.016698 -7.07 -4.8    0.0             0           0
# 23055              0   0.016883 -7.07 -4.8    0.0             0           0
# 23056              0   0.016321 -7.07 -4.8    0.0             0           0
#
# [410 rows x 7 columns]
#
# DataFrame 40:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 23057             13   0.016686 -7.07 -4.8    0.0             3           1
# 23058              0   0.016998 -7.07 -4.8    0.0             0           0
# 23059              0   0.016423 -7.07 -4.8    0.0             0           0
# 23060              0   0.016681 -7.07 -4.8    0.0             0           0
# 23061              0   0.017098 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 23513              0   0.016787 -7.07 -4.8    0.0             0           0
# 23514              0   0.016833 -7.07 -4.8    0.0             0           0
# 23515              0   0.016463 -7.07 -4.8    0.0             0           0
# 23516              0   0.016803 -7.07 -4.8    0.0             0           0
# 23517              0   0.016526 -7.07 -4.8    0.0             0           0
#
# [461 rows x 7 columns]
#
# DataFrame 41:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 23518             15   0.016675 -7.07 -4.8    0.0000             5           1
# 23519              0   0.016793 -7.07 -4.8    0.0000             0           0
# 23520              0   0.016511 -7.07 -4.8    0.0000             0           0
# 23521              0   0.016696 -7.07 -4.8    0.0000             0           0
# 23522              0   0.016611 -7.07 -4.8    0.0000             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 24077              0   0.016483 -7.07 -4.8  346.9305             0           0
# 24078              0   0.017254 -7.07 -4.8  346.9305             0           0
# 24079              0   0.016478 -7.07 -4.8  346.9305             0           0
# 24080              0   0.016911 -7.07 -4.8  346.9305             0           0
# 24081              0   0.015853 -7.07 -4.8  346.9305             0           0
#
# [564 rows x 7 columns]
#
# DataFrame 42:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 24082             14   0.016817 -7.07 -4.8  346.9305             4           1
# 24083              0   0.016784 -7.07 -4.8  346.9305             0           0
# 24084              0   0.016727 -7.07 -4.8  346.9305             0           0
# 24085              0   0.016924 -7.07 -4.8  346.9305             0           0
# 24086              0   0.016298 -7.07 -4.8  346.9305             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 24645              0   0.016982 -7.07 -4.8   32.0648             0           0
# 24646              0   0.016524 -7.07 -4.8   32.0648             0           0
# 24647              0   0.016405 -7.07 -4.8   32.0648             0           0
# 24648              0   0.016700 -7.07 -4.8   32.0648             0           0
# 24649              0   0.016779 -7.07 -4.8   32.0648             0           0
#
# [568 rows x 7 columns]
#
# DataFrame 43:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 24650             13   0.016446 -7.07 -4.8  32.0648             3           1
# 24651              0   0.016903 -7.07 -4.8  32.0648             0           0
# 24652              0   0.016569 -7.07 -4.8  32.0648             0           0
# 24653              0   0.016529 -7.07 -4.8  32.0648             0           0
# 24654              0   0.016655 -7.07 -4.8  32.0648             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 25161              0   0.016620 -7.07 -4.8   0.0000             0           0
# 25162              0   0.016710 -7.07 -4.8   0.0000             0           0
# 25163              0   0.016674 -7.07 -4.8   0.0000             0           0
# 25164              0   0.016698 -7.07 -4.8   0.0000             0           0
# 25165              0   0.016501 -7.07 -4.8   0.0000             0           0
#
# [516 rows x 7 columns]
#
# DataFrame 44:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 25166             12   0.016800 -7.07 -4.8    0.0             2           1
# 25167              0   0.016799 -7.07 -4.8    0.0             0           0
# 25168              0   0.016600 -7.07 -4.8    0.0             0           0
# 25169              0   0.016801 -7.07 -4.8    0.0             0           0
# 25170              0   0.016596 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 25774              0   0.016556 -7.07 -4.8    0.0             0           0
# 25775              0   0.016959 -7.07 -4.8    0.0             0           0
# 25776              0   0.016789 -7.07 -4.8    0.0             0           0
# 25777              0   0.016706 -7.07 -4.8    0.0             0           0
# 25778              0   0.016151 -7.07 -4.8    0.0             0           0
#
# [613 rows x 7 columns]
#
# DataFrame 45:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 25779             16   0.016632 -7.07 -4.8    0.0             6           1
# 25780              0   0.016903 -7.07 -4.8    0.0             0           0
# 25781              0   0.016697 -7.07 -4.8    0.0             0           0
# 25782              0   0.016503 -7.07 -4.8    0.0             0           0
# 25783              0   0.016804 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 26340              0   0.016697 -7.07 -4.8    0.0             0           0
# 26341              0   0.016637 -7.07 -4.8    0.0             0           0
# 26342              0   0.016701 -7.07 -4.8    0.0             0           0
# 26343              0   0.016162 -7.07 -4.8    0.0             0           0
# 26344              0   0.016399 -7.07 -4.8    0.0             0           0
#
# [566 rows x 7 columns]
#
# DataFrame 46:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 26345             13   0.016803 -7.07 -4.8    0.0             3           1
# 26346              0   0.016678 -7.07 -4.8    0.0             0           0
# 26347              0   0.016517 -7.07 -4.8    0.0             0           0
# 26348              0   0.016819 -7.07 -4.8    0.0             0           0
# 26349              0   0.016684 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 26776              0   0.016498 -7.07 -4.8    0.0             0           0
# 26777              0   0.016800 -7.07 -4.8    0.0             0           0
# 26778              0   0.016623 -7.07 -4.8    0.0             0           0
# 26779              0   0.016791 -7.07 -4.8    0.0             0           0
# 26780              0   0.016581 -7.07 -4.8    0.0             0           0
#
# [436 rows x 7 columns]
#
# DataFrame 47:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 26781             14   0.016607 -7.07 -4.8    0.0             4           1
# 26782              0   0.016700 -7.07 -4.8    0.0             0           0
# 26783              0   0.016694 -7.07 -4.8    0.0             0           0
# 26784              0   0.016604 -7.07 -4.8    0.0             0           0
# 26785              0   0.016737 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 27577              0   0.016289 -7.07 -4.8    0.0             0           0
# 27578              0   0.016893 -7.07 -4.8    0.0             0           0
# 27579              0   0.016817 -7.07 -4.8    0.0             0           0
# 27580              0   0.016806 -7.07 -4.8    0.0             0           0
# 27581              0   0.016598 -7.07 -4.8    0.0             0           0
#
# [801 rows x 7 columns]
#
# DataFrame 48:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 27582             12   0.016607 -7.07 -4.8    0.0             2           1
# 27583              0   0.016889 -7.07 -4.8    0.0             0           0
# 27584              0   0.016394 -7.07 -4.8    0.0             0           0
# 27585              0   0.016807 -7.07 -4.8    0.0             0           0
# 27586              0   0.016497 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 28412              0   0.016708 -7.07 -4.8    0.0             0           0
# 28413              0   0.016594 -7.07 -4.8    0.0             0           0
# 28414              0   0.016709 -7.07 -4.8    0.0             0           0
# 28415              0   0.016685 -7.07 -4.8    0.0             0           0
# 28416              0   0.016395 -7.07 -4.8    0.0             0           0
#
# [835 rows x 7 columns]
#
# DataFrame 49:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 28417             16   0.016705 -7.07 -4.8    0.0             6           1
# 28418              0   0.017091 -7.07 -4.8    0.0             0           0
# 28419              0   0.016334 -7.07 -4.8    0.0             0           0
# 28420              0   0.016682 -7.07 -4.8    0.0             0           0
# 28421              0   0.016720 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 28904              0   0.016705 -7.07 -4.8    0.0             0           0
# 28905              0   0.016796 -7.07 -4.8    0.0             0           0
# 28906              0   0.016500 -7.07 -4.8    0.0             0           0
# 28907              0   0.016709 -7.07 -4.8    0.0             0           0
# 28908              0   0.016591 -7.07 -4.8    0.0             0           0
#
# [492 rows x 7 columns]
#
# DataFrame 50:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 28909             14   0.016608 -7.07 -4.8   0.0000             4           1
# 28910              0   0.017001 -7.07 -4.8   0.0000             0           0
# 28911              0   0.016443 -7.07 -4.8   0.0000             0           0
# 28912              0   0.016453 -7.07 -4.8   0.0000             0           0
# 28913              0   0.016895 -7.07 -4.8   0.0000             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 29374              0   0.016593 -7.07 -4.8  27.6436             0           0
# 29375              0   0.016685 -7.07 -4.8  27.6436             0           0
# 29376              0   0.016807 -7.07 -4.8  27.6436             0           0
# 29377              0   0.016620 -7.07 -4.8  27.6436             0           0
# 29378              0   0.016851 -7.07 -4.8  27.6436             0           0
#
# [470 rows x 7 columns]
#
# DataFrame 51:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 29379             16   0.016433 -7.07 -4.8  27.6436             6           1
# 29380              0   0.016861 -7.07 -4.8  27.6436             0           0
# 29381              0   0.016582 -7.07 -4.8  27.6436             0           0
# 29382              0   0.016555 -7.07 -4.8  27.6436             0           0
# 29383              0   0.016698 -7.07 -4.8  27.6436             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 29870              0   0.016602 -7.07 -4.8   0.0000             0           0
# ...
# 56521              0   0.016596 -7.07 -4.8    0.0000             0           0
# 56522              0   0.016850 -7.07 -4.8    0.0000             0           0
# 56523              0   0.016469 -7.07 -4.8    0.0000             0           0
# 56524              0   0.016581 -7.07 -4.8    0.0000             0           0
# 56525              0   0.016806 -7.07 -4.8    0.0000             0           0
#
# [364 rows x 7 columns]
#
# DataFrame 106:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 56526             16   0.016697 -7.07 -4.8    0.0             6           1
# 56527              0   0.016803 -7.07 -4.8    0.0             0           0
# 56528              0   0.016376 -7.07 -4.8    0.0             0           0
# 56529              0   0.016867 -7.07 -4.8    0.0             0           0
# 56530              0   0.016754 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 56968              0   0.016528 -7.07 -4.8    0.0             0           0
# 56969              0   0.016865 -7.07 -4.8    0.0             0           0
# 56970              0   0.016911 -7.07 -4.8    0.0             0           0
# 56971              0   0.016480 -7.07 -4.8    0.0             0           0
# 56972              0   0.016598 -7.07 -4.8    0.0             0           0
#
# [447 rows x 7 columns]
#
# DataFrame 107:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 56973             12   0.016697 -7.07 -4.8    0.0             2           1
# 56974              0   0.016808 -7.07 -4.8    0.0             0           0
# 56975              0   0.016452 -7.07 -4.8    0.0             0           0
# 56976              0   0.016737 -7.07 -4.8    0.0             0           0
# 56977              0   0.016398 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 57443              0   0.016692 -7.07 -4.8    0.0             0           0
# 57444              0   0.016707 -7.07 -4.8    0.0             0           0
# 57445              0   0.016598 -7.07 -4.8    0.0             0           0
# 57446              0   0.016708 -7.07 -4.8    0.0             0           0
# 57447              0   0.016514 -7.07 -4.8    0.0             0           0
#
# [475 rows x 7 columns]
#
# DataFrame 108:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 57448             15   0.016917 -7.07 -4.8    0.000             5           1
# 57449              0   0.016670 -7.07 -4.8    0.000             0           0
# 57450              0   0.016535 -7.07 -4.8    0.000             0           0
# 57451              0   0.016686 -7.07 -4.8    0.000             0           0
# 57452              0   0.016722 -7.07 -4.8    0.000             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 57966              0   0.016555 -7.07 -4.8  338.903             0           0
# 57967              0   0.016829 -7.07 -4.8  338.903             0           0
# 57968              0   0.016791 -7.07 -4.8  338.903             0           0
# 57969              0   0.016816 -7.07 -4.8  338.903             0           0
# 57970              0   0.016575 -7.07 -4.8  338.903             0           0
#
# [523 rows x 7 columns]
#
# DataFrame 109:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 57971             11   0.016606 -7.07 -4.8  338.903             1           1
# 57972              0   0.016882 -7.07 -4.8  338.903             0           0
# 57973              0   0.016429 -7.07 -4.8  338.903             0           0
# 57974              0   0.016521 -7.07 -4.8  338.903             0           0
# 57975              0   0.016874 -7.07 -4.8  338.903             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 58331              0   0.016397 -7.07 -4.8    0.000             0           0
# 58332              0   0.016800 -7.07 -4.8    0.000             0           0
# 58333              0   0.016698 -7.07 -4.8    0.000             0           0
# 58334              0   0.016479 -7.07 -4.8    0.000             0           0
# 58335              0   0.016454 -7.07 -4.8    0.000             0           0
#
# [365 rows x 7 columns]
#
# DataFrame 110:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 58336             14   0.016888 -7.07 -4.8   0.0000             4           1
# 58337              0   0.016981 -7.07 -4.8   0.0000             0           0
# 58338              0   0.016515 -7.07 -4.8   0.0000             0           0
# 58339              0   0.016685 -7.07 -4.8   0.0000             0           0
# 58340              0   0.016601 -7.07 -4.8   0.0000             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 58766              0   0.016495 -7.07 -4.8  40.1152             0           0
# 58767              0   0.016902 -7.07 -4.8  40.1152             0           0
# 58768              0   0.016519 -7.07 -4.8  40.1152             0           0
# 58769              0   0.016688 -7.07 -4.8  40.1152             0           0
# 58770              0   0.016690 -7.07 -4.8  40.1152             0           0
#
# [435 rows x 7 columns]
#
# DataFrame 111:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 58771             15   0.016603 -7.07 -4.8   40.1152             5           1
# 58772              0   0.016941 -7.07 -4.8   40.1152             0           0
# 58773              0   0.016460 -7.07 -4.8   40.1152             0           0
# 58774              0   0.016614 -7.07 -4.8   40.1152             0           0
# 58775              0   0.016888 -7.07 -4.8   40.1152             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 59312              0   0.016710 -7.07 -4.8  344.6216             0           0
# 59313              0   0.016526 -7.07 -4.8  344.6216             0           0
# 59314              0   0.016692 -7.07 -4.8  344.6216             0           0
# 59315              0   0.016566 -7.07 -4.8  344.6216             0           0
# 59316              0   0.016819 -7.07 -4.8  344.6216             0           0
#
# [546 rows x 7 columns]
#
# DataFrame 112:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 59317             14   0.016383 -7.07 -4.8  344.6216             4           1
# 59318              0   0.017040 -7.07 -4.8  344.6216             0           0
# 59319              0   0.016557 -7.07 -4.8  344.6216             0           0
# 59320              0   0.016610 -7.07 -4.8  344.6216             0           0
# 59321              0   0.016697 -7.07 -4.8  344.6216             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 59791              0   0.017020 -7.07 -4.8   45.7651             0           0
# 59792              0   0.016419 -7.07 -4.8   45.7651             0           0
# 59793              0   0.016785 -7.07 -4.8   45.7651             0           0
# 59794              0   0.016624 -7.07 -4.8   45.7651             0           0
# 59795              0   0.016672 -7.07 -4.8   45.7651             0           0
#
# [479 rows x 7 columns]
#
# DataFrame 113:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 59796             12   0.016599 -7.07 -4.8  45.7651             2           1
# 59797              0   0.016900 -7.07 -4.8  45.7651             0           0
# 59798              0   0.016399 -7.07 -4.8  45.7651             0           0
# 59799              0   0.016630 -7.07 -4.8  45.7651             0           0
# 59800              0   0.016878 -7.07 -4.8  45.7651             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 60360              0   0.016692 -7.07 -4.8   0.0000             0           0
# 60361              0   0.016696 -7.07 -4.8   0.0000             0           0
# 60362              0   0.016805 -7.07 -4.8   0.0000             0           0
# 60363              0   0.016698 -7.07 -4.8   0.0000             0           0
# 60364              0   0.016345 -7.07 -4.8   0.0000             0           0
#
# [569 rows x 7 columns]
#
# DataFrame 114:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 60365             14   0.016788 -7.07 -4.8   0.0000             4           1
# 60366              0   0.016866 -7.07 -4.8   0.0000             0           0
# 60367              0   0.016504 -7.07 -4.8   0.0000             0           0
# 60368              0   0.016702 -7.07 -4.8   0.0000             0           0
# 60369              0   0.016673 -7.07 -4.8   0.0000             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 60822              0   0.016878 -7.07 -4.8  36.0624             0           0
# 60823              0   0.016601 -7.07 -4.8  36.0624             0           0
# 60824              0   0.016607 -7.07 -4.8  36.0624             0           0
# 60825              0   0.016589 -7.07 -4.8  36.0624             0           0
# 60826              0   0.016809 -7.07 -4.8  36.0624             0           0
#
# [462 rows x 7 columns]
#
# DataFrame 115:
#        TrackingStamp  TimeStamp     X    Y    Angle  PosterNumber  TrialStamp
# 60827             16   0.016512 -7.07 -4.8  36.0624             6           1
# 60828              0   0.016804 -7.07 -4.8  36.0624             0           0
# 60829              0   0.015962 -7.07 -4.8  36.0624             0           0
# 60830              0   0.017395 -7.07 -4.8  36.0624             0           0
# 60831              0   0.016532 -7.07 -4.8  36.0624             0           0
# ...              ...        ...   ...  ...      ...           ...         ...
# 61282              0   0.016884 -7.07 -4.8   0.0000             0           0
# 61283              0   0.016703 -7.07 -4.8   0.0000             0           0
# 61284              0   0.016623 -7.07 -4.8   0.0000             0           0
# 61285              0   0.016682 -7.07 -4.8   0.0000             0           0
# 61286              0   0.016692 -7.07 -4.8   0.0000             0           0
#
# [460 rows x 7 columns]
#
# DataFrame 116:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 61287             13   0.016499 -7.07 -4.8    0.0             3           1
# 61288              0   0.017001 -7.07 -4.8    0.0             0           0
# 61289              0   0.016400 -7.07 -4.8    0.0             0           0
# 61290              0   0.016376 -7.07 -4.8    0.0             0           0
# 61291              0   0.017047 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 61706              0   0.016616 -7.07 -4.8    0.0             0           0
# 61707              0   0.016704 -7.07 -4.8    0.0             0           0
# 61708              0   0.016580 -7.07 -4.8    0.0             0           0
# 61709              0   0.016798 -7.07 -4.8    0.0             0           0
# 61710              0   0.016639 -7.07 -4.8    0.0             0           0
#
# [424 rows x 7 columns]
#
# DataFrame 117:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 61711             12   0.016472 -7.07 -4.8    0.0             2           1
# 61712              0   0.016991 -7.07 -4.8    0.0             0           0
# 61713              0   0.016518 -7.07 -4.8    0.0             0           0
# 61714              0   0.016686 -7.07 -4.8    0.0             0           0
# 61715              0   0.016697 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 62663              0   0.016248 -7.07 -4.8    0.0             0           0
# 62664              0   0.016690 -7.07 -4.8    0.0             0           0
# 62665              0   0.016700 -7.07 -4.8    0.0             0           0
# 62666              0   0.016604 -7.07 -4.8    0.0             0           0
# 62667              0   0.016553 -7.07 -4.8    0.0             0           0
#
# [957 rows x 7 columns]
#
# DataFrame 118:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 62668             15   0.017056 -7.07 -4.8    0.0000             5           1
# 62669              0   0.016408 -7.07 -4.8    0.0000             0           0
# 62670              0   0.016587 -7.07 -4.8    0.0000             0           0
# 62671              0   0.016625 -7.07 -4.8    0.0000             0           0
# 62672              0   0.016810 -7.07 -4.8    0.0000             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 63197              0   0.016614 -7.07 -4.8  346.9213             0           0
# 63198              0   0.016703 -7.07 -4.8  346.9213             0           0
# 63199              0   0.016572 -7.07 -4.8  346.9213             0           0
# 63200              0   0.016700 -7.07 -4.8  346.9213             0           0
# 63201              0   0.016704 -7.07 -4.8  346.9213             0           0
#
# [534 rows x 7 columns]
#
# DataFrame 119:
#        TrackingStamp  TimeStamp     X    Y     Angle  PosterNumber  TrialStamp
# 63202             12   0.016503 -7.07 -4.8  346.9213             2           1
# 63203              0   0.016916 -7.07 -4.8  346.9213             0           0
# 63204              0   0.016363 -7.07 -4.8  346.9213             0           0
# 63205              0   0.016722 -7.07 -4.8  346.9213             0           0
# 63206              0   0.016503 -7.07 -4.8  346.9213             0           0
# ...              ...        ...   ...  ...       ...           ...         ...
# 63685              0   0.016807 -7.07 -4.8    0.0000             0           0
# 63686              0   0.016596 -7.07 -4.8    0.0000             0           0
# 63687              0   0.016597 -7.07 -4.8    0.0000             0           0
# 63688              0   0.016719 -7.07 -4.8    0.0000             0           0
# 63689              0   0.016705 -7.07 -4.8    0.0000             0           0
#
# [488 rows x 7 columns]
#
# DataFrame 120:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 63690             15   0.016480 -7.07 -4.8    0.0             5           1
# 63691              0   0.016487 -7.07 -4.8    0.0             0           0
# 63692              0   0.016908 -7.07 -4.8    0.0             0           0
# 63693              0   0.016618 -7.07 -4.8    0.0             0           0
# 63694              0   0.016721 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 64547              0   0.016367 -7.07 -4.8    0.0             0           0
# 64548              0   0.016649 -7.07 -4.8    0.0             0           0
# 64549              0   0.016711 -7.07 -4.8    0.0             0           0
# 64550              0   0.016606 -7.07 -4.8    0.0             0           0
# 64551              0   0.016704 -7.07 -4.8    0.0             0           0
#
# [862 rows x 7 columns]
#
# DataFrame 121:
#        TrackingStamp  TimeStamp     X    Y  Angle  PosterNumber  TrialStamp
# 64552             12   0.016487 -7.07 -4.8    0.0             2           1
# 64553              0   0.017100 -7.07 -4.8    0.0             0           0
# 64554              0   0.016301 -7.07 -4.8    0.0             0           0
# 64555              0   0.016799 -7.07 -4.8    0.0             0           0
# 64556              0   0.016812 -7.07 -4.8    0.0             0           0
# ...              ...        ...   ...  ...    ...           ...         ...
# 65487              0   0.016521 -7.07 -4.8    0.0             0           0
# 65488              0   0.016907 -7.07 -4.8    0.0             0           0
# 65489              0   0.016595 -7.07 -4.8    0.0             0           0
# 65490              0   0.016783 -7.07 -4.8    0.0             0           0
# 65491              0   0.016701 -7.07 -4.8    0.0             0           0
#
# [940 rows x 7 columns]

# %%
n_plots = len(dfs)
n_cols = 6
n_rows = math.ceil(n_plots/n_cols)
poster_animal = ""
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 6, n_rows * 8))
axes = axes.flatten()

for i, (df, ax) in enumerate(zip(dfs, axes)):
    poster_number = df.loc[df['TrialStamp'] == 1, 'PosterNumber'].values[0] if not df.loc[df['TrialStamp'] == 1, 'PosterNumber'].empty else 'Unknown'
    if (poster_number == 1):
        poster_animal = "Cat"
    elif (poster_number == 2):
        poster_animal = "Hippo"
    elif (poster_number == 3):
        poster_animal = "Fox"
    elif (poster_number == 4):
        poster_animal = "Rabbit"
    elif (poster_number == 5):
        poster_animal = "Crocodile"
    elif (poster_number == 6):
        poster_animal = "Pig"
        
    ax.set_ylim(y_min, y_max)
    ax.set_xlim(x_min, x_max)
    ax.scatter(df[sorted("X")], df[sorted("Y")], marker = '.')
    ax.set_title(f'Trial {i + 1} (Poster {poster_animal})')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_aspect('equal')
    ax.add_patch(Rectangle((-5.9350, 15.0350), 9.9581, 3.8, color='black', fill=True))
    # ax.plot([-5.9350, 4.0231], [15.0350, 15.0350], color='black')
    # ax.plot([-5.9350, -5.9350], [18.8350, 15.0350], color='black')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])
plt.tight_layout()
plt.show()
# One thing to be noted is that the sim spawns you in the wall and teleports you out the second you move
# Which shows the slight height increase from approx -5, to a few points above it. 
# I have no idea how Trial 1 happened

# %%
dfs1 = []
dfs2 = []
dfs3 = []
dfs4 = []
dfs5 = []
dfs6 = []
for df in dfs:
    select_poster_number = df.loc[df['TrialStamp'] == 1, 'PosterNumber'].values[0] if not df.loc[df['TrialStamp'] == 1, 'PosterNumber'].empty else 'Unknown'
    if (select_poster_number == 1):
        dfs1.append(df)
    elif (select_poster_number == 2):
        dfs2.append(df)
    elif (select_poster_number == 3):
        dfs3.append(df)
    elif (select_poster_number == 4):
        dfs4.append(df)
    elif (select_poster_number == 5):
        dfs5.append(df)
    elif (select_poster_number == 6):
        dfs6.append(df)
dfs_lists = [dfs1, dfs2, dfs3, dfs4, dfs5, dfs6]

# %% [markdown]
# This script combines all of the graphs above into one per type of poster. Each trial is represented by a different color, and the red x represents the location of the poster.

# %%
def plot_all(ax, dfs, tuple):

    poster_num, target_x, target_y, animal = tuple[0], tuple[1], tuple[2], tuple[3]

    for i, df in enumerate(dfs):
        ax.scatter(df['X'], df['Y'], marker = '.', label = f'Trial {i + 1}')
   
    ax.add_patch(Rectangle((-5.9350, 15.0350), 9.9581, 3.8, color='black', fill=True))
    
    ax.scatter(target_x, target_y, color='red', marker = 'x', s=60, linewidths=3)

    ax.set_ylim(y_min, y_max)
    ax.set_xlim(x_min, x_max)
    ax.set_title(f'All Trials for Poster {poster_num}: {animal}')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_aspect('equal')

fig, axes = plt.subplots(2,3,figsize=(18, 12))
axes = axes.flatten()

for ax, dfs_list, poster in zip(axes, dfs_lists, posters):
    plot_all(ax, dfs_list, poster)

plt.tight_layout()
plt.show()
#add green or red dot for correct

# %% [markdown]
# Grabs the x and y values of all the final values for each trial, placed into their own sets organized by poster.

# %%
x_values_sets = []
y_values_sets = []

for dfs_set in dfs_lists:
    x_values = []
    y_values = []
    
    for df in dfs_set: 
        filtered_df = df.loc[df['TrialStamp'] == 3]

        if not filtered_df.empty: 
            x_values.extend(filtered_df['X'].tolist())
            y_values.extend(filtered_df['Y'].tolist())

    x_values_sets.append(x_values)
    y_values_sets.append(y_values)

# %% [markdown]
# Function to calculate the all types of error? from each end point of each trial to the location of the poster.

# %%
euclidean_distances = []
# add x and y data separately (add variance stats of each axis)
def euclidean_distance_error(x_values, y_values, tuple):
    target_x, target_y = tuple[1], tuple[2]
    errors = []
    
    for x, y in zip(x_values, y_values):
        euclidean_error = math.sqrt((target_x - x) ** 2 + (target_y - y) ** 2)
        errors.append(euclidean_error)
    euclidean_distance = sum(errors) / len(errors)
    return euclidean_distance

for x_values, y_values, poster in zip(x_values_sets, y_values_sets, posters):
    distance = round(euclidean_distance_error(x_values, y_values, poster),5)
    euclidean_distances.append(distance)

for i, distance in enumerate(euclidean_distances):
    print(f"Euclidean distance for {posters[i][3]}: {distance}")
# Out:
# Euclidean distance for Cat: 2.27766
# Euclidean distance for Hippo: 2.22573
# Euclidean distance for Fox: 3.23464
# Euclidean distance for Rabbit: 3.03523
# Euclidean distance for Crocodile: 3.65607
# Euclidean distance for Pig: 1.0312

# %%
mean_absolute_errors = []

def mean_absolute_error(x_values, y_values, tuple):
    target_x, target_y = tuple[1], tuple[2]
    abs_errors = []
    
    for x, y in zip(x_values, y_values):
        absolute_error = abs(target_x - x) + abs(target_y - y)
        abs_errors.append(absolute_error)
    mean_absolute_error = sum(abs_errors) / len(abs_errors)
    return mean_absolute_error

for x_values, y_values, poster in zip(x_values_sets, y_values_sets, posters):
    absolute = round(mean_absolute_error(x_values, y_values, poster),5)
    mean_absolute_errors.append(absolute) 
    
for i, absolute in enumerate(mean_absolute_errors):
    print(f"Mean Absolute Error for {posters[i][3]}: {absolute}")
# Out:
# Mean Absolute Error for Cat: 2.67569
# Mean Absolute Error for Hippo: 2.61451
# Mean Absolute Error for Fox: 3.71034
# Mean Absolute Error for Rabbit: 4.16511
# Mean Absolute Error for Crocodile: 4.35506
# Mean Absolute Error for Pig: 1.33269

# %%
root_mean_square_errors = []

def root_mean_square_error(x_values, y_values, tuple):
    target_x, target_y = tuple[1], tuple[2]
    rmse_errors = []
    
    for x, y in zip(x_values, y_values):
        root_mean_square_error = (target_x - x) ** 2 + (target_y - y) ** 2
        rmse_errors.append(root_mean_square_error)
    rmse_error = math.sqrt(sum(rmse_errors) / len(rmse_errors))
    return rmse_error

for x_values, y_values, poster in zip(x_values_sets, y_values_sets, posters):
    rmse_error = round(root_mean_square_error(x_values, y_values, poster),5)
    root_mean_square_errors.append(rmse_error) 
    
for i, rmse_error in enumerate(root_mean_square_errors):
    print(f"Root Mean Square Error for {posters[i][3]}: {rmse_error}")
# Out:
# Mean Absolute Error for Cat: 2.3527
# Mean Absolute Error for Hippo: 2.34722
# Mean Absolute Error for Fox: 3.28868
# Mean Absolute Error for Rabbit: 3.30803
# Mean Absolute Error for Crocodile: 3.71012
# Mean Absolute Error for Pig: 1.21281

# %%
def plot_all(ax, dfs, tuple, x_values, y_values):

    poster_num, target_x, target_y, animal = tuple[0], tuple[1], tuple[2], tuple[3]
    
    for x, y in zip(x_values, y_values):
        ax.scatter(x, y, marker = '.', color='blue')

    #create the rectangle in the back right of the environment:
    ax.add_patch(Rectangle((-5.9350, 15.0350), 9.9581, 3.8, color='black', fill=True))
    #ax.plot([-5.9350, 4.0231], [15.0350, 15.0350], color='black')
    #ax.plot([-5.9350, -5.9350], [18.8350, 15.0350], color='black')
    
    ax.scatter(target_x, target_y, color='red', marker = 'x', s=60, linewidths=3)

    ax.set_ylim(y_min, y_max)
    ax.set_xlim(x_min, x_max)
    ax.set_title(f'All Trials for Poster {poster_num}: {animal}')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_aspect('equal')

fig, axes = plt.subplots(2,3,figsize=(18, 12))
axes = axes.flatten()

for ax, dfs_list, poster, x_values, y_values in zip(axes, dfs_lists, posters, x_values_sets, y_values_sets):
    plot_all(ax, dfs_list, poster, x_values, y_values)

plt.tight_layout()
plt.show()
# Make more data but without resetting position

# %%
def plot_all(ax, dfs, tuple, x_values, y_values):

    poster_num, target_x, target_y, animal = tuple[0], tuple[1], tuple[2], tuple[3]
    
    for df, x, y in zip(dfs, x_values, y_values):
        if 4 in df['TrialStamp'].values:
            ax.scatter(x, y, marker='.', color='red', s=40)
        else:
            ax.scatter(x, y, marker='.', color='green', s=40)

    ax.add_patch(Rectangle((-5.9350, 15.0350), 9.9581, 3.8, color='black', fill=True))
    
    ax.scatter(target_x, target_y, color='red', marker = 'x', s=60, linewidths=3)

    ax.set_ylim(y_min, y_max)
    ax.set_xlim(x_min, x_max)
    ax.set_title(f'All Trials for Poster {poster_num}: {animal}')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_aspect('equal')

fig, axes = plt.subplots(2,3,figsize=(18, 12))
axes = axes.flatten()

for ax, dfs_list, poster, x_values, y_values in zip(axes, dfs_lists, posters, x_values_sets, y_values_sets):
    plot_all(ax, dfs_list, poster, x_values, y_values)

plt.tight_layout()
plt.show()
